# %%
import re

# %%
text="my phone no is 5789462583"
n=re.findall(r"\d",text)# \d digit
n
# Out:
# ['5', '7', '8', '9', '4', '6', '2', '5', '8', '3']

# %%
t="i like machine learning"
m=re.search("machine learning",t) # returns first occurins of the pattern
print(m)
print(m.group())
# Out:
# <re.Match object; span=(7, 23), match='machine learning'>
# machine learning

# %%
t=" machine learning i like the ml"
match=re.match("machine learning",t) #only match  search begin of the string
print(m)
print(m.group())
# Out:
# <re.Match object; span=(7, 23), match='machine learning'>
# machine learning

# %%
tex="how are you?//"
s=re.sub(r"[?/]","",tex) #sub - remove the delimiters,""replace the text
s
# Out:
# 'how are you'
